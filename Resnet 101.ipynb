# %%
import tensorflow as tf
from backbone.blocks.resnet_block import identity_block, convolutional_block, conv_first_block

# %%
def Resnet101(input_shape=(224, 224, 3)):
    # Stage 1
    x, input_layer = conv_first_block(input_shape=input_shape)
    
    # Stage 2
    x = convolutional_block(x, [64, 64, 256], (3, 3), strides=(1, 1))
    x = identity_block(x, [64, 64, 256], (3, 3))
    x = identity_block(x, [64, 64, 256], (3, 3))
    
    # Stage 3
    x = convolutional_block(x, [128, 128, 512], (3, 3), strides=(2, 2))
    x = identity_block(x, [128, 128, 512], (3, 3))
    x = identity_block(x, [128, 128, 512], (3, 3))
    x = identity_block(x, [128, 128, 512], (3, 3))
    
    # Stage 4
    x = convolutional_block(x, [256, 256, 1024], (3, 3), strides=(2, 2))
    # Use a for loop to add the blocks - too many times to copy and paste
    for i in range(22):
        x = identity_block(x, [256, 256, 1024], (3,3))
        
    # Stage 5
    x = convolutional_block(x, [512, 512, 2048], (3, 3), strides=(2, 2))
    x = identity_block(x, [512, 512, 2048], (3, 3))
    x = identity_block(x, [512, 512, 2048], (3, 3))
    
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    return tf.keras.Model(inputs=input_layer, outputs=x, name='Resnet50')

# %% [markdown]
# # Train on mnist again

# %%
model = tf.keras.Sequential()
model.add(Resnet101(input_shape=(28, 28, 1)))
model.add(tf.keras.layers.Dense(64))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Activation('softmax'))

# %%
from matplotlib import pyplot as plt

# %%
(train_img, train_label), (test_img, test_label) = tf.keras.datasets.mnist.load_data()

# %%
def preproc_img(img, label):
    img = tf.cast(img, tf.float32)
    img = img / 255.
    
    return img, tf.one_hot(label, 10)

# %%
epochs = 10
batch_size = 128
learning_rate = 1e-4

# %%
train_data = tf.data.Dataset.from_tensor_slices((train_img, train_label))
train_data = train_data.map(preproc_img)
train_data = train_data.cache()
train_data = train_data.shuffle(len(train_img))
train_data = train_data.repeat(1)
train_data = train_data.batch(batch_size, drop_remainder=True)
train_data = train_data.prefetch(tf.data.experimental.AUTOTUNE)

# %%
test_data = tf.data.Dataset.from_tensor_slices((test_img, test_label))
test_data = test_data.map(preproc_img)
test_data = test_data.cache()
train_data = train_data.repeat(1)
test_data = test_data.batch(batch_size)
test_data = test_data.prefetch(tf.data.experimental.AUTOTUNE)

# %%
model.compile(
    tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy', metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    epochs=epochs,
    validation_data=test_data
)
# Out:
# Epoch 1/10
# 468/468 [==============================] - 43s 92ms/step - loss: 2.1267 - accuracy: 0.2305 - val_loss: 2.3613 - val_accuracy: 0.2260
# Epoch 2/10
# 468/468 [==============================] - 42s 89ms/step - loss: 1.1832 - accuracy: 0.6031 - val_loss: 0.7845 - val_accuracy: 0.7539
# Epoch 3/10
# 468/468 [==============================] - 42s 90ms/step - loss: 0.6388 - accuracy: 0.8130 - val_loss: 0.4043 - val_accuracy: 0.8836
# Epoch 4/10
# 468/468 [==============================] - 42s 90ms/step - loss: 0.4016 - accuracy: 0.8864 - val_loss: 0.3168 - val_accuracy: 0.9105
# Epoch 5/10
# 468/468 [==============================] - 43s 91ms/step - loss: 0.2802 - accuracy: 0.9223 - val_loss: 0.2970 - val_accuracy: 0.9178
# Epoch 6/10
# 468/468 [==============================] - 43s 91ms/step - loss: 0.2039 - accuracy: 0.9441 - val_loss: 0.2562 - val_accuracy: 0.9335
# Epoch 7/10
# 468/468 [==============================] - 43s 91ms/step - loss: 0.1557 - accuracy: 0.9574 - val_loss: 0.2695 - val_accuracy: 0.9354
# Epoch 8/10
# 468/468 [==============================] - 43s 92ms/step - loss: 0.1289 - accuracy: 0.9643 - val_loss: 0.2390 - val_accuracy: 0.9413
# Epoch 9/10
# 468/468 [==============================] - 43s 92ms/step - loss: 0.1156 - accuracy: 0.9685 - val_loss: 0.2077 - val_accuracy: 0.9528
# Epoch 10/10
# 468/468 [==============================] - 43s 93ms/step - loss: 0.1022 - accuracy: 0.9726 - val_loss: 0.1898 - val_accuracy: 0.9595

# %%
plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.title('Loss History')
plt.plot(history.history['loss'], '--bo',label='loss')
plt.plot(history.history['val_loss'], '--yo',label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(222)
plt.title('Accuracy History')
plt.plot(history.history['accuracy'], '--bo',label='acc')
plt.plot(history.history['val_accuracy'], '--yo',label='val_acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate

# %%
from sklearn.metrics import classification_report, confusion_matrix, matthews_corrcoef
import seaborn as sns

# %%
y_true = test_label
y_pred = model.predict(test_data)
y_pred = y_pred.argmax(axis=1)

# %%
print(classification_report(y_true, y_pred))
print('MCC :{}'.format(round(matthews_corrcoef(y_true, y_pred) * 100, 2)))
conf_mat = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(15, 10))
sns.heatmap(
    conf_mat, annot=True, fmt=''
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.99      0.98      0.99      1135
#            2       0.97      0.94      0.96      1032
#            3       0.96      0.96      0.96      1010
#            4       0.97      0.96      0.96       982
#            5       0.94      0.96      0.95       892
#            6       0.97      0.97      0.97       958
#            7       0.97      0.95      0.96      1028
#            8       0.91      0.97      0.94       974
#            9       0.96      0.91      0.94      1009
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# MCC :95.5
# <AxesSubplot:>
